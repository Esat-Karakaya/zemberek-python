# %%
import time
import logging

from zemberek import (
    TurkishSpellChecker,
    TurkishSentenceNormalizer,
    TurkishSentenceExtractor,
    TurkishMorphology,
    TurkishTokenizer
)
# Out:
# /home/esat/Desktop/zemberek-python/zemberek/tokenization/antlr/turkish_lexer.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
morphology = TurkishMorphology.create_with_defaults()
# Out:
# 2026-01-19 20:24:49,989 - zemberek.morphology.turkish_morphology - INFO
# Msg: TurkishMorphology instance initialized in 8.53206205368042

# %%
# SINGLE WORD MORPHOLOGICAL ANALYSIS
results = morphology.analyze("koşmak")
for result in results:
    print(result)
print("\n")
# Out:
# [koşmak:Verb] koş:Verb|mak:Inf1→Noun+A3sg

# %%
# SENTENCE ANALYSIS AND DISAMBIGUATION
sentence = "Tüm oyunları Sally'e gösterdik"
analysis = morphology.analyze_sentence(sentence)
after = morphology.disambiguate(sentence, analysis)

print("\nAfter disambiguation")
for s in after.best_analysis():
    print(s.format_string())
# Out:
# After disambiguation
# [tüm:Det] tüm:Det
# [oyun:Noun] oyun:Noun+lar:A3pl+ı:Acc
# [UNK:Unk, Unk] Sally'e:Unknown
# [göstermek:Verb] göster:Verb+di:Past+k:A1pl

# %%
from utils import generate_word

generate_word("gel", "Verb", ["Aor", "A1sg"])
# Out:
# 2026-01-19 20:25:02,866 - root - WARNING
# Msg: Couldn't add suffixes: ['Aor', 'A1sg'] to "gel" via zemberek's own method. Deploying work around
# 'gelerim'

# %%
from utils import add_Inf1_suffix
add_Inf1_suffix("gel")
# Out:
# /home/esat/Desktop/zemberek-python/zemberek/tokenization/antlr/turkish_lexer.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from utils import add_Inf1_suffix
# ----> 2 add_Inf1_suffix("gel")
#
# File ~/Desktop/zemberek-python/utils.py:193, in add_Inf1_suffix(verb)
#     192 def add_Inf1_suffix(verb: str) -> str:
# --> 193     is_frontal = TurkishAlphabet.get_last_vowel(s=verb).is_frontal()
#     194     sfx = "mek" if is_frontal else "mak"
#     195     return verb+sfx
#
# TypeError: TurkishAlphabet.get_last_vowel() missing 1 required positional argument: 'self'
