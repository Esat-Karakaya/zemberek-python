# %%
import time
import logging

from zemberek import (
    TurkishSpellChecker,
    TurkishSentenceNormalizer,
    TurkishSentenceExtractor,
    TurkishMorphology,
    TurkishTokenizer
)
# Out:
# /home/esat/Desktop/zemberek-python/zemberek/morphology/turkish_morphology.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
morphology = TurkishMorphology.create_with_defaults()
# Out:
# 2026-01-18 18:51:35,460 - zemberek.morphology.turkish_morphology - INFO
# Msg: TurkishMorphology instance initialized in 8.135392904281616

# %%
# SINGLE WORD MORPHOLOGICAL ANALYSIS
results = morphology.analyze("Jazz'a")
for result in results:
    print(result)
print("\n")
# Out:
# [Jazz:Noun, Prop] jazz:Noun+A3sg+a:Dat

# %%
# SENTENCE ANALYSIS AND DISAMBIGUATION
sentence = "Tüm oyunları Sally'e gösterdik"
analysis = morphology.analyze_sentence(sentence)
after = morphology.disambiguate(sentence, analysis)

print("\nAfter disambiguation")
for s in after.best_analysis():
    print(s.format_string())
# Out:
# After disambiguation
# [tüm:Det] tüm:Det
# [oyun:Noun] oyun:Noun+lar:A3pl+ı:Acc
# [UNK:Unk, Unk] Sally'e:Unknown
# [göstermek:Verb] göster:Verb+di:Past+k:A1pl

# %%
from utils import generate_word

generate_word("bir")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from utils import generate_word
# ----> 3 generate_word("bir", "Dist")
#
# TypeError: generate_word() missing 1 required positional argument: 'suffixes'
